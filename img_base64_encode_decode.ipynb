# %%
import base64
with open("13b63796.jpeg", "rb") as img_file:
    my_string = base64.b64encode(img_file.read())
print(my_string)
# Out:
# b'...'

# %%
import base64
st='...'
imgdata = base64.b64decode(st)
filename = 'some_imag.jpg'  
with open(filename, 'wb') as f:
    f.write(imgdata)
